# %%
import tweepy
import pandas as pd
import re
import pickle
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
import discord
from discord.ext import commands
import twitter
import xgboost as xgb
import pandas as pd
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
#from thinc.api import *
import spacy
nlp =spacy.load('en_core_web_sm')
import speech_recognition as sr

# %%
from tkinter import *
import tkinter as tk
import ipywidgets as widgets
from IPython.display import display, clear_output
from tkinter import *
from PIL import ImageTk, Image
import json
import warnings
from tkinter import ttk
from tkcalendar import Calendar,DateEntry
from tkinter.messagebox import showinfo

# %%
consumer_key="DR3UsIQHEJJdd4dSuY6ksPvnn"
consumer_secret="VP7CKOz8csUACKcFnEzjKp9ZrZeUuHt9U100bRQiad1QXgYSAI"
access_token="1319530376956706818-wauMwDmVaGDBAvbodTuO3haJO4YuAM"
access_token_secret="kyrSD9VXGxh6es9dN2RQu8SyH7HCDdq7f3hVZerVYyZrh"
bearer_token ="AAAAAAAAAAAAAAAAAAAAAP%2BYaAEAAAAAohNmsYv8LaQ0CsG0yYxt7so%2BYkg%3DtOgdpwX8QXNVrXp5ZH2VuyWV3thAByXjbx6kuIo2yVpUlYi3oN"

# %%
from credentials import *

import tweepy
from time import sleep

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
#import SmallInterface

# %%
# %run  ./SmallInterface.ipynb

# %%
print(username.get())
print(n.get())
print(calinidate.get())
print(calenddate.get())
print(var.get())
print(var1.get())
print(texto.get())
# Out:
# evoespueblo
# Politician
# 4/13/22
# 4/19/22
# 1
# 50

# %%
from datetime import datetime
input_strini = calinidate.get()+" 00:00:00"
input_str = calenddate.get()+" 00:00:00"

dt_objectini = datetime.strptime(
  input_strini, '%m/%d/%y %H:%M:%S')

dt_object = datetime.strptime(
  input_str, '%m/%d/%y %H:%M:%S')

print(dt_objectini.isoformat("T") + "Z")
print(dt_object.isoformat("T") + "Z")
# Out:
# 2022-04-13T00:00:00Z
# 2022-04-19T00:00:00Z

# %%
import tweepy
import pandas as pd
import json

# %%
import requests
client = tweepy.Client( bearer_token=bearer_token, 
                        consumer_key=consumer_key, 
                        consumer_secret=consumer_secret, 
                        access_token=access_token, 
                        access_token_secret=access_token_secret, 
                        return_type = requests.Response,
                        wait_on_rate_limit=True)

# %%
#username=name.value
#var2=IntVar()
import re

texto1=texto.get()
texto1=texto1.lower()
palabras=['olivia','peru','olombia']
print(texto1)
if(username.get()!=""):
    query = 'from:'+username.get()+' -is:retweet'
    start_time = dt_objectini.isoformat("T") + "Z"
    end_time = dt_object.isoformat("T") + "Z"
    # get max. 50 tweets
    if(var.get==2):
        tweets = client.search_recent_tweets(query=query,
                                         start_time=start_time,
                                         end_time=end_time,
                                         tweet_fields = ["created_at", "text", "source"],
                                         max_results = var1.get())
    else:
        tweets = client.search_recent_tweets(query=query,
                                         start_time=start_time,
                                         end_time=end_time,
                                         tweet_fields = ["created_at", "text", "source"],
                                         max_results = 100)
else:
    #texto1=StringVar()
    texto1=texto.get()
    texto1=texto1.lower()
    dictwitter = dict([
      ('olivia', 'LuchoXBolivia'),
      ('eru', 'presidenciaperu'),
      ('olombia', 'IvanDuque'),
      ('gentina', 'alferdez'),
      ('ile', 'gabrielboric'),
      ('cuador', 'LassoGuillermo'),
      ('guay', 'LuisLacallePou'),
      ('araguay', 'MaritoAbdo'),
      ('sil', 'jairbolsonaro'),
      ('anama', 'NitoCortizo'),
      ('zuela', 'PresidencialVen'),
      ('mala', 'GuatemalaGob'),
      ('salvado', 'nayibbukele'),
      ('ica', 'presidenciacr'),
      ('ico', 'lopezobrador_'),
    ])
    i=0
    for p in dictwitter:
        cuenta=dictwitter.get(p)
               
        if(re.search(p,texto1)):
            #print('La palabra`{}`se ha encontrado en la frase'.format(p,cuenta))
            username1=cuenta
            i=i+1
        else:
            pass
    
    if (i==0):
        print('There is not concidences')
    else:
        query = 'from:'+username1+' -is:retweet'
        start_time = "2022-04-12T00:00:00Z"
        end_time = "2022-04-18T00:00:00Z"
        tweets = client.search_recent_tweets(query=query,
                                         start_time=start_time,
                                         end_time=end_time,
                                         tweet_fields = ["created_at", "text", "source"],
                                         max_results = 100)

# %%
tweets
# Out:
# <Response [200]>

# %%
import pandas as pd

# Save data as dictionary
tweets_dict = tweets.json()

# %%
tweets_dict
# Out:
# {'data': [{'id': '1516039030609227776',
#    'text': 'Desde las 05:00 am desarrollamos una reunión de evaluación y planificación política con el Gobernador de #Cochabamba y asambleístas nacionales y departamentales; alcaldes y concejales. https://t.co/Zypai614Hf',
#    'created_at': '2022-04-18T13:00:46.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1516011241747140614',
#    'text': 'El MAS-IPSP es una organización política viva que debate y resuelve internamente sus contradicciones. A la hora de defender la dignidad, soberanía y economía de nuestro pueblo, actuamos con la verdad, unidad y solidaridad; sin mezquindad ni falsedad. ¡Somos pueblo, somos MAS!',
#    'created_at': '2022-04-18T11:10:20.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1516011098746544129',
#    'text': 'A diferencia de partidos opositores que se dedican a sus campañas de odio y racismo contra Evo, nuestro instrumento político que llegó al gobierno gracias al voto del pueblo, tiene un plan de trabajo para reconstruir la economía y la democracia destruidas por el régimen de facto',
#    'created_at': '2022-04-18T11:09:46.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1516010937408491526',
#    'text': 'Hago un llamado a nuestra militancia a no dejarse confundir con las mentiras e intrigas de la derecha golpista y sus medios que busca dividir y desestabilizar. La unidad del bloque popular del MAS-IPSP está intacta. Nuestras organizaciones trabajan de la mano con nuestro gobierno',
#    'created_at': '2022-04-18T11:09:08.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515824052648255492',
#    'text': 'Fuimos al municipio de Anzaldo, comunidad de Tijraska, donde visitamos la represa, iniciada en nuestra gestión, que abastecerá a 170 Ha. de cultivos. Nos alegra su pronta inauguración. https://t.co/hZLOjEFAM5',
#    'created_at': '2022-04-17T22:46:31.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515785734145327111',
#    'text': 'Nuestro agradecimiento al hermano Hernán Colque, alcalde de Toro Toro, autoridades y pueblo del municipio, en provincia Charcas, departamento de Potosí, por su cálido recibimiento y la visita al Parque Nacional de Toro Toro de huellas de dinosaurios, cavernas y sitios milenarios. https://t.co/bQRDAV1G34',
#    'created_at': '2022-04-17T20:14:15.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515755468760616961',
#    'text': 'Recorrimos hoy la majestuosa e impresionante caverna de Umajalanta, en Toro Toro, la más grande de A. Latina, con rocas milenarias, aguas cristalinas y murciélagos que nos hicieron vivir una aventura maravillosa.\nInvito al pueblo boliviano y al mundo a visitarla. ¡Les encantará! https://t.co/PWVv3F4ydV',
#    'created_at': '2022-04-17T18:13:59.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515739532070694919',
#    'text': 'La prensa quiere hacernos aparecer divididos y enfrentados pero no hay nada de eso. Estamos viendo y convencidos de que no hay división del MAS-IPSP en el recorrido que hacemos por distintos departamentos de #Bolivia organizando el registro de  militantes.',
#    'created_at': '2022-04-17T17:10:40.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515721332478005249',
#    'text': 'Lo más importante es la unidad en base a un movimiento político que garantiza la liberación de la patria, con un programa para mucho tiempo que viene del pueblo, con un MAS-IPSP que no claudica en su posición ideológica antimperialista y anticolonialista.',
#    'created_at': '2022-04-17T15:58:21.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515721109034856449',
#    'text': 'Como movimiento político más grande de la historia en Bolivia, el MAS-IPSP y organizaciones sociales, no podemos actuar en función a las intenciones de la derecha para dividirnos reflejadas en los grandes titulares de su prensa porque tenemos con el pueblo un programa que cumplir',
#    'created_at': '2022-04-17T15:57:27.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515720496511258625',
#    'text': 'Las portadas de la prensa de derecha reflejan las estrategias para dividirnos porque nos tienen miedo, les molesta que nuestro movimiento político, MAS IPSP, esté integrado por movimientos sociales del área urbana y rural de #Bolivia y tenga un programa más allá del Bicentenario.',
#    'created_at': '2022-04-17T15:55:01.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515720179967094785',
#    'text': 'Los afanes de la derecha desde que el pueblo retomó el gobierno por la vía democrática es dividir al MAS-IPSP. Decían, primero, Evo manda a Lucho y, ahora, dicen que Evo dará golpe a Lucho. En el fondo, nos tienen miedo y eso no debe preocuparnos, lo importante es la unidad (1/4)',
#    'created_at': '2022-04-17T15:53:46.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515698319254822922',
#    'text': 'Los enemigos de Evo son amigos del imperio y sumisos a él por lo que no nos molesta que hablen en nuestra contra; estamos acostumbrados a sus ataques como todo líder, en cualquier parte del mundo, que lucha y defiende los intereses de su pueblo.',
#    'created_at': '2022-04-17T14:26:54.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515672874807447556',
#    'text': 'Nuestro saludo revolucionario a la Central Obrera Boliviana (COB) en el aniversario de su creación,\xa017 de abril\xa0de\xa01952, por su lucha incansable por la dignidad de los trabajadores y su permanente y firme defensa de la soberanía de la patria y la nacionalización de los recursos. https://t.co/1Soc5hgnQU',
#    'created_at': '2022-04-17T12:45:47.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515427835824979976',
#    'text': 'Lamentamos el fallecimiento del escritor boliviano Enrique Rocha Monroy, a los 89 años.\nNuestras sentidas condolencias a su hermano, Ramón Rocha Monroy, y a toda su familia por esta irreparable pérdida.\nTe acompañamos en tu dolor hermano Ramón. https://t.co/DoHEl83axW',
#    'created_at': '2022-04-16T20:32:06.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515427245241819140',
#    'text': 'Lindo encuentro con jóvenes de las seis Federaciones, juntos reflexionamos sobre políticas económicas y sociales para Bolivia. \nMuchos son hijos de mis compañeros, con quienes luchamos sindicalmente.\nNos alegra ver que son jóvenes con mucha convicción para trabajar por la patria https://t.co/x7lau8Y4u3',
#    'created_at': '2022-04-16T20:29:45.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515346176371044357',
#    'text': 'Si el cristianismo tiene como principios luchar por los pobres y servir con sacrificio a la gente humilde, seguir la fe religiosa, católica o cristiana, es asumir la misión de amar la vida y a la humanidad, en hermandad y solidaridad. https://t.co/1zkXxgmju0',
#    'created_at': '2022-04-16T15:07:36.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515078477963149312',
#    'text': 'Nos da mucha alegría llegar a #Tarija en el día que celebra su aniversario.\n\nHemos socializado la inscripción de nuevos militantes del MAS-IPSP y sostuvimos una reunión con dirigentes y autoridades del departamento. https://t.co/s4teE4bCNV',
#    'created_at': '2022-04-15T21:23:52.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1515005163894837250',
#    'text': 'Estuvimos en Sucre, #Chuquisaca para socializar la inscripción de nuevos militantes y para sostener una reunión con dirigentes y autoridades del departamento. https://t.co/WNnTrsPRdh',
#    'created_at': '2022-04-15T16:32:33.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514954236127326216',
#    'text': 'En este #ViernesSanto nos unimos a las reflexiones y oraciones de nuestro pueblo que recuerda el sacrificio de Jesucristo por la humanidad. \n\nUna enseñanza importante del cristianismo es luchar por los más pobres. La solidaridad es la base de una sociedad con respeto y paz social https://t.co/vJDkt6q5py',
#    'created_at': '2022-04-15T13:10:11.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514925839288356868',
#    'text': 'Rendimos nuestro homenaje al hermano pueblo de la chura Tarija en el 205 aniversario de la Batalla de la Tablada que nos trae a la memoria la victoria decisiva de Eustaquio "Moto" Méndez y sus "montoneros" sobre las fuerzas realistas. #Tarija es tierra fecunda de amor por Bolivia https://t.co/LtnleudzCR',
#    'created_at': '2022-04-15T11:17:20.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514730707280609286',
#    'text': 'Nuestra digna representante Angélica Barrios nos llena de orgullo y deja en alto el nombre de nuestra querida #Bolivia. Medalla de oro y campeona en la categoría open damas del XXXIII Campeonato Panamericano de Ráquet, es un gran ejemplo de superación de las nuevas generaciones. https://t.co/Uo5JEG7qm2',
#    'created_at': '2022-04-14T22:21:57.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514698654506004487',
#    'text': 'Con dirigentes de San Julián y Yapacaní y de Interculturales de Santa Cruz coincidimos en fortalecer la unidad para defender la patria y nuestra Revolución Democrática y Cultural en reuniones desarrolladas el martes y hoy. Próxima reunión será con interculturales del departamento https://t.co/o7VvBBbUy8',
#    'created_at': '2022-04-14T20:14:35.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514662592538677251',
#    'text': 'Nuestro profundo pesar por la partida del Hno. Freddy Rincón, estrella del fútbol latinoamericano y mundial que fue baluarte de la selección de #Colombia y grandes equipos como el Corinthians y Real Madrid. Nuestra solidaridad a su familia y a la hinchada que lamenta su ausencia. https://t.co/XXtNacNXNn',
#    'created_at': '2022-04-14T17:51:17.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514569466755092480',
#    'text': 'Al defender a golpistas derechistas que enjuiciados por asaltar el poder, robar al Estado y masacrar a nuestros hermanos, EE.UU busca impunidad para esos delitos y violaciones de DD.HH. Busca la desestabilización política para impedir la justicia que piden las víctimas del golpe.',
#    'created_at': '2022-04-14T11:41:14.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514569342842724352',
#    'text': 'El último informe del Departamento de Estado es prueba de la conspiración de EEUU contra el pueblo y la democracia de Bolivia. Empezaron con las falsas acusaciones de la DEA para defenestrar a Evo y dirigentes del Trópico y así dividir al MAS-IPSP. Ahora acusan a nuestro gobierno',
#    'created_at': '2022-04-14T11:40:45.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514281309983719427',
#    'text': 'Con su informe político y mentiroso, EE.UU. habla de "impunidad" en Cuba, Nicaragua, Venezuela, México, Bolivia y Perú, para chantajear a sus pueblos. El mundo condena la verdadera impunidad de un país que a nombre de "libertad" promueve intervenciones armadas y golpes de Estado.',
#    'created_at': '2022-04-13T16:36:12.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514279785094168583',
#    'text': 'El informe del Departamento de Estado, amplificado por medios de la derecha golpista como si fuera la verdad irrebatible, busca santificar a los autores de masacres de hermanos indígenas en el gobierno de facto. Igual que los informes de la DEA, intenta desestabilizar al gobierno',
#    'created_at': '2022-04-13T16:30:09.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514265637828415494',
#    'text': '#EEUU, responsable de las peores masacres, intervenciones armadas y golpes de Estado en el mundo, no tiene ninguna moral para hablar de Derechos Humanos ni justicia. Con su informe que defiende al gobierno de facto, atenta contra la democracia recuperada por el pueblo en urnas.',
#    'created_at': '2022-04-13T15:33:56.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514207764817465347',
#    'text': 'Los pueblos libres y unidos contra el intervencionismo imperialista celebran este día para reivindicar la defensa de la democracia como legado de amor a la Patria Grande, que nos dejó el Libertador Simón Bolívar. Golpismo nunca más. Recordamos siempre que "cada 11, tendrá su 13”.',
#    'created_at': '2022-04-13T11:43:58.000Z',
#    'source': 'Twitter for Android'},
#   {'id': '1514207589793378309',
#    'text': 'En el #DíaDeLaDignidadNacional honramos la memoria del hermano comandante Hugo Chávez Frías y el coraje del digno pueblo venezolano que derrotó hace 20 años al golpe de empresarios, medios de comunicación, jerarquía de la Iglesia Católica y partidos de derecha sumisos a EE.UU https://t.co/8q9jyQV4Fi',
#    'created_at': '2022-04-13T11:43:16.000Z',
#    'source': 'Twitter for Android'}],
#  'meta': {'newest_id': '1516039030609227776',
#   'oldest_id': '1514207589793378309',
#   'result_count': 31}}

# %%
import pandas as pd
# Extract "data" value from dictionary
tweets_data = tweets_dict["data"] 

# Transform to pandas Dataframe
df = pd.json_normalize(tweets_data)

# %%
df.head()
# Out:
#                     id                                               text  \
# 0  1516039030609227776  Desde las 05:00 am desarrollamos una reunión d...
# 1  1516011241747140614  El MAS-IPSP es una organización política viva ...
# 2  1516011098746544129  A diferencia de partidos opositores que se ded...
# 3  1516010937408491526  Hago un llamado a nuestra militancia a no deja...
# 4  1515824052648255492  Fuimos al municipio de Anzaldo, comunidad de T...
#
#                  created_at               source
# 0  2022-04-18T13:00:46.000Z  Twitter for Android
# 1  2022-04-18T11:10:20.000Z  Twitter for Android
# 2  2022-04-18T11:09:46.000Z  Twitter for Android
# 3  2022-04-18T11:09:08.000Z  Twitter for Android
# 4  2022-04-17T22:46:31.000Z  Twitter for Android

# %%
len(df)
# Out:
# 31

# %%
df1=df.iloc[0:len(df)]['text']

df1
# Out:
# 0     Desde las 05:00 am desarrollamos una reunión d...
# 1     El MAS-IPSP es una organización política viva ...
# 2     A diferencia de partidos opositores que se ded...
# 3     Hago un llamado a nuestra militancia a no deja...
# 4     Fuimos al municipio de Anzaldo, comunidad de T...
# 5     Nuestro agradecimiento al hermano Hernán Colqu...
# 6     Recorrimos hoy la majestuosa e impresionante c...
# 7     La prensa quiere hacernos aparecer divididos y...
# 8     Lo más importante es la unidad en base a un mo...
# 9     Como movimiento político más grande de la hist...
# 10    Las portadas de la prensa de derecha reflejan ...
# 11    Los afanes de la derecha desde que el pueblo r...
# 12    Los enemigos de Evo son amigos del imperio y s...
# 13    Nuestro saludo revolucionario a la Central Obr...
# 14    Lamentamos el fallecimiento del escritor boliv...
# 15    Lindo encuentro con jóvenes de las seis Federa...
# 16    Si el cristianismo tiene como principios lucha...
# 17    Nos da mucha alegría llegar a #Tarija en el dí...
# 18    Estuvimos en Sucre, #Chuquisaca para socializa...
# 19    En este #ViernesSanto nos unimos a las reflexi...
# 20    Rendimos nuestro homenaje al hermano pueblo de...
# 21    Nuestra digna representante Angélica Barrios n...
# 22    Con dirigentes de San Julián y Yapacaní y de I...
# 23    Nuestro profundo pesar por la partida del Hno....
# 24    Al defender a golpistas derechistas que enjuic...
# 25    El último informe del Departamento de Estado e...
# 26    Con su informe político y mentiroso, EE.UU. ha...
# 27    El informe del Departamento de Estado, amplifi...
# 28    #EEUU, responsable de las peores masacres, int...
# 29    Los pueblos libres y unidos contra el interven...
# 30    En el #DíaDeLaDignidadNacional honramos la mem...
# Name: text, dtype: object

# %%
#This splits all the sentences up which makes it easier for us to work with

all_sentences = []

for word in df1:
    all_sentences.append(word)

all_sentences
#df1 = df.to_string()

#df_split = df1.split()

#df_split
lines = list()
for line in all_sentences:    
    words = line.split()
    for w in words: 
       lines.append(w)


print(lines)
# Out:
# ['Desde', 'las', '05:00', 'am', 'desarrollamos', 'una', 'reunión', 'de', 'evaluación', 'y', 'planificación', 'política', 'con', 'el', 'Gobernador', 'de', '#Cochabamba', 'y', 'asambleístas', 'nacionales', 'y', 'departamentales;', 'alcaldes', 'y', 'concejales.', 'https://t.co/Zypai614Hf', 'El', 'MAS-IPSP', 'es', 'una', 'organización', 'política', 'viva', 'que', 'debate', 'y', 'resuelve', 'internamente', 'sus', 'contradicciones.', 'A', 'la', 'hora', 'de', 'defender', 'la', 'dignidad,', 'soberanía', 'y', 'economía', 'de', 'nuestro', 'pueblo,', 'actuamos', 'con', 'la', 'verdad,', 'unidad', 'y', 'solidaridad;', 'sin', 'mezquindad', 'ni', 'falsedad.', '¡Somos', 'pueblo,', 'somos', 'MAS!', 'A', 'diferencia', 'de', 'partidos', 'opositores', 'que', 'se', 'dedican', 'a', 'sus', 'campañas', 'de', 'odio', 'y', 'racismo', 'contra', 'Evo,', 'nuestro', 'instrumento', 'político', 'que', 'llegó', 'al', 'gobierno', 'gracias', 'al', 'voto', 'del', 'pueblo,', 'tiene', 'un', 'plan', 'de', 'trabajo', 'para', 'reconstruir', 'la', 'economía', 'y', 'la', 'democracia', 'destruidas', 'por', 'el', 'régimen', 'de', 'facto', 'Hago', 'un', 'llamado', 'a', 'nuestra', 'militancia', 'a', 'no', 'dejarse', 'confundir', 'con', 'las', 'mentiras', 'e', 'intrigas', 'de', 'la', 'derecha', 'golpista', 'y', 'sus', 'medios', 'que', 'busca', 'dividir', 'y', 'desestabilizar.', 'La', 'unidad', 'del', 'bloque', 'popular', 'del', 'MAS-IPSP', 'está', 'intacta.', 'Nuestras', 'organizaciones', 'trabajan', 'de', 'la', 'mano', 'con', 'nuestro', 'gobierno', 'Fuimos', 'al', 'municipio', 'de', 'Anzaldo,', 'comunidad', 'de', 'Tijraska,', 'donde', 'visitamos', 'la', 'represa,', 'iniciada', 'en', 'nuestra', 'gestión,', 'que', 'abastecerá', 'a', '170', 'Ha.', 'de', 'cultivos.', 'Nos', 'alegra', 'su', 'pronta', 'inauguración.', 'https://t.co/hZLOjEFAM5', 'Nuestro', 'agradecimiento', 'al', 'hermano', 'Hernán', 'Colque,', 'alcalde', 'de', 'Toro', 'Toro,', 'autoridades', 'y', 'pueblo', 'del', 'municipio,', 'en', 'provincia', 'Charcas,', 'departamento', 'de', 'Potosí,', 'por', 'su', 'cálido', 'recibimiento', 'y', 'la', 'visita', 'al', 'Parque', 'Nacional', 'de', 'Toro', 'Toro', 'de', 'huellas', 'de', 'dinosaurios,', 'cavernas', 'y', 'sitios', 'milenarios.', 'https://t.co/bQRDAV1G34', 'Recorrimos', 'hoy', 'la', 'majestuosa', 'e', 'impresionante', 'caverna', 'de', 'Umajalanta,', 'en', 'Toro', 'Toro,', 'la', 'más', 'grande', 'de', 'A.', 'Latina,', 'con', 'rocas', 'milenarias,', 'aguas', 'cristalinas', 'y', 'murciélagos', 'que', 'nos', 'hicieron', 'vivir', 'una', 'aventura', 'maravillosa.', 'Invito', 'al', 'pueblo', 'boliviano', 'y', 'al', 'mundo', 'a', 'visitarla.', '¡Les', 'encantará!', 'https://t.co/PWVv3F4ydV', 'La', 'prensa', 'quiere', 'hacernos', 'aparecer', 'divididos', 'y', 'enfrentados', 'pero', 'no', 'hay', 'nada', 'de', 'eso.', 'Estamos', 'viendo', 'y', 'convencidos', 'de', 'que', 'no', 'hay', 'división', 'del', 'MAS-IPSP', 'en', 'el', 'recorrido', 'que', 'hacemos', 'por', 'distintos', 'departamentos', 'de', '#Bolivia', 'organizando', 'el', 'registro', 'de', 'militantes.', 'Lo', 'más', 'importante', 'es', 'la', 'unidad', 'en', 'base', 'a', 'un', 'movimiento', 'político', 'que', 'garantiza', 'la', 'liberación', 'de', 'la', 'patria,', 'con', 'un', 'programa', 'para', 'mucho', 'tiempo', 'que', 'viene', 'del', 'pueblo,', 'con', 'un', 'MAS-IPSP', 'que', 'no', 'claudica', 'en', 'su', 'posición', 'ideológica', 'antimperialista', 'y', 'anticolonialista.', 'Como', 'movimiento', 'político', 'más', 'grande', 'de', 'la', 'historia', 'en', 'Bolivia,', 'el', 'MAS-IPSP', 'y', 'organizaciones', 'sociales,', 'no', 'podemos', 'actuar', 'en', 'función', 'a', 'las', 'intenciones', 'de', 'la', 'derecha', 'para', 'dividirnos', 'reflejadas', 'en', 'los', 'grandes', 'titulares', 'de', 'su', 'prensa', 'porque', 'tenemos', 'con', 'el', 'pueblo', 'un', 'programa', 'que', 'cumplir', 'Las', 'portadas', 'de', 'la', 'prensa', 'de', 'derecha', 'reflejan', 'las', 'estrategias', 'para', 'dividirnos', 'porque', 'nos', ' ...

# %%
#Removing Punctuation

lines = [re.sub(r'[^A-Za-z0-9]+', '', x) for x in lines]

lines

lines2 = []

for word in lines:
    if word != '':
        lines2.append(word)

# %%
#This is stemming the words to their root
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='spanish')

stem = []
for word in lines2:
    stem.append(s_stemmer.stem(word))
    
stem
# Out:
# ['desd',
#  'las',
#  '0500',
#  'am',
#  'desarroll',
#  'una',
#  'reunin',
#  'de',
#  'evaluacin',
#  'y',
#  'planificacin',
#  'poltic',
#  'con',
#  'el',
#  'gobern',
#  'de',
#  'cochabamb',
#  'y',
#  'asamblest',
#  'nacional',
#  'y',
#  'departamental',
#  'alcald',
#  'y',
#  'concejal',
#  'httpstcozypai614hf',
#  'el',
#  'masipsp',
#  'es',
#  'una',
#  'organizacin',
#  'poltic',
#  'viv',
#  'que',
#  'debat',
#  'y',
#  'resuelv',
#  'intern',
#  'sus',
#  'contradiccion',
#  'a',
#  'la',
#  'hor',
#  'de',
#  'defend',
#  'la',
#  'dignid',
#  'soberan',
#  'y',
#  'econom',
#  'de',
#  'nuestr',
#  'puebl',
#  'actu',
#  'con',
#  'la',
#  'verd',
#  'unid',
#  'y',
#  'solidar',
#  'sin',
#  'mezquind',
#  'ni',
#  'falsed',
#  'som',
#  'puebl',
#  'som',
#  'mas',
#  'a',
#  'diferent',
#  'de',
#  'part',
#  'opositor',
#  'que',
#  'se',
#  'dedic',
#  'a',
#  'sus',
#  'camp',
#  'de',
#  'odi',
#  'y',
#  'racism',
#  'contr',
#  'evo',
#  'nuestr',
#  'instrument',
#  'poltic',
#  'que',
#  'lleg',
#  'al',
#  'gobiern',
#  'graci',
#  'al',
#  'vot',
#  'del',
#  'puebl',
#  'tien',
#  'un',
#  'plan',
#  'de',
#  'trabaj',
#  'par',
#  'reconstru',
#  'la',
#  'econom',
#  'y',
#  'la',
#  'democraci',
#  'destru',
#  'por',
#  'el',
#  'rgim',
#  'de',
#  'fact',
#  'hag',
#  'un',
#  'llam',
#  'a',
#  'nuestr',
#  'milit',
#  'a',
#  'no',
#  'dej',
#  'confund',
#  'con',
#  'las',
#  'mentir',
#  'e',
#  'intrig',
#  'de',
#  'la',
#  'derech',
#  'golpist',
#  'y',
#  'sus',
#  'medi',
#  'que',
#  'busc',
#  'divid',
#  'y',
#  'desestabiliz',
#  'la',
#  'unid',
#  'del',
#  'bloqu',
#  'popul',
#  'del',
#  'masipsp',
#  'est',
#  'intact',
#  'nuestr',
#  'organiz',
#  'trabaj',
#  'de',
#  'la',
#  'man',
#  'con',
#  'nuestr',
#  'gobiern',
#  'fuim',
#  'al',
#  'municipi',
#  'de',
#  'anzald',
#  'comun',
#  'de',
#  'tijrask',
#  'dond',
#  'visit',
#  'la',
#  'repres',
#  'inici',
#  'en',
#  'nuestr',
#  'gestin',
#  'que',
#  'abastec',
#  'a',
#  '170',
#  'ha',
#  'de',
#  'cultiv',
#  'nos',
#  'alegr',
#  'su',
#  'pront',
#  'inauguracin',
#  'httpstcohzlojefam5',
#  'nuestr',
#  'agradec',
#  'al',
#  'herman',
#  'hernn',
#  'colqu',
#  'alcald',
#  'de',
#  'tor',
#  'tor',
#  'autor',
#  'y',
#  'puebl',
#  'del',
#  'municipi',
#  'en',
#  'provinci',
#  'charc',
#  'departament',
#  'de',
#  'pot',
#  'por',
#  'su',
#  'clid',
#  'recib',
#  'y',
#  'la',
#  'visit',
#  'al',
#  'parqu',
#  'nacional',
#  'de',
#  'tor',
#  'tor',
#  'de',
#  'huell',
#  'de',
#  'dinosauri',
#  'cavern',
#  'y',
#  'siti',
#  'milenari',
#  'httpstcobqrdav1g34',
#  'recorr',
#  'hoy',
#  'la',
#  'majestu',
#  'e',
#  'impresion',
#  'cavern',
#  'de',
#  'umajalant',
#  'en',
#  'tor',
#  'tor',
#  'la',
#  'ms',
#  'grand',
#  'de',
#  'a',
#  'latin',
#  'con',
#  'roc',
#  'milenari',
#  'agu',
#  'cristalin',
#  'y',
#  'murcilag',
#  'que',
#  'nos',
#  'hic',
#  'viv',
#  'una',
#  'aventur',
#  'maravill',
#  'invit',
#  'al',
#  'puebl',
#  'bolivian',
#  'y',
#  'al',
#  'mund',
#  'a',
#  'visit',
#  'les',
#  'encant',
#  'httpstcopwvv3f4ydv',
#  'la',
#  'prens',
#  'quier',
#  'hac',
#  'aparec',
#  'divid',
#  'y',
#  'enfrent',
#  'per',
#  'no',
#  'hay',
#  'nad',
#  'de',
#  'eso',
#  'estam',
#  'viend',
#  'y',
#  'convenc',
#  'de',
#  'que',
#  'no',
#  'hay',
#  'divisin',
#  'del',
#  'masipsp',
#  'en',
#  'el',
#  'recorr',
#  'que',
#  'hac',
#  'por',
#  'distint',
#  'departament',
#  'de',
#  'bolivi',
#  'organiz',
#  'el',
#  'registr',
#  'de',
#  'milit',
#  'lo',
#  'ms',
#  'import',
#  'es',
#  'la',
#  'unid',
#  'en',
#  'bas',
#  'a',
#  'un',
#  'movimient',
#  'poltic',
#  'que',
#  'garantiz',
#  'la',
#  'liberacin',
#  'de',
#  'la',
#  'patri',
#  'con',
#  'un',
#  'program',
#  'par',
#  'much',
#  'tiemp',
#  'que',
#  'vien',
#  'del',
#  'puebl',
#  'con',
#  'un',
#  'masipsp',
#  'que',
#  'no',
#  'claudic',
#  'en',
#  'su',
#  'posicin',
#  'ideolg',
#  'antimperial',
#  'y',
#  'anticolonial',
#  'com',
#  'movimient',
#  'poltic',
#  'ms',
#  'grand',
#  'de',
#  'la',
#  'histori',
#  'en',
#  'bolivi',
#  'el',
#  'masipsp',
#  'y',
#  'organiz',
#  'social',
#  'no',
#  'pod',
#  'actu',
#  'en',
#  'funcin',
#  'a',
#  'las',
#  'intencion',
#  'de',
#  'la',
#  'derech',
#  'par',
#  'divid',
#  'reflej',
#  'en',
#  'los',
#  'grand',
#  'titular',
#  'de',
#  'su',
#  'prens',
#  'porqu',
#  'ten',
#  'con',
#  'el',
#  'puebl',
#  'un',
#  'program',
#  'que',
#  'cumpl',
#  'las',
#  'port',
#  'de',
#  'la',
#  'prens',
#  'de',
#  'derech',
#  'reflej',
#  'las',
#  'estrategi',
#  'par',
#  'divid',
#  'porqu',
#  'nos',
#  'tien',
#  'mied',
#  'les',
#  'molest',
#  'que',
#  'nuestr',
#  'movimient',
#  'poltic',
#  'mas',
#  'ipsp',
#  'est',
#  'integr',
#  'por',
#  'movimient',
#  'social',
#  'del',
#  'rea',
#  'urban',
#  'y',
#  'rural',
#  'de',
#  'bolivi',
#  'y',
#  'teng',
#  'un',
#  'program',
#  'ms',
#  'all',
#  'del',
#  'bicentenari',
#  'los',
#  'afan',
#  'de',
#  'la',
#  'derech',
#  'desd',
#  'que',
#  'el',
#  'puebl',
#  'retom',
#  'el',
#  'gobiern',
#  'por',
#  'la',
#  'va',
#  'democrt',
#  'es',
#  'divid',
#  'al',
#  'masipsp',
#  'dec',
#  'primer',
#  'evo',
#  'mand',
#  'a',
#  'luch',
#  'y',
#  'ahor',
#  'dic',
#  'que',
#  'evo',
#  'dar',
#  'golp',
#  'a',
#  'luch',
#  'en',
#  'el',
#  'fond',
#  'nos',
#  'tien',
#  'mied',
#  'y',
#  'eso',
#  'no',
#  'deb',
#  'preocup',
#  'lo',
#  'import',
#  'es',
#  'la',
#  'unid',
#  '14',
#  'los',
#  'enemig',
#  'de',
#  'evo',
#  'son',
#  'amig',
#  'del',
#  'imperi',
#  'y',
#  'sumis',
#  'a',
#  'l',
#  'por',
#  'lo',
#  'que',
#  'no',
#  'nos',
#  'molest',
#  'que',
#  'habl',
#  'en',
#  'nuestr',
#  'contr',
#  'estam',
#  'acostumbr',
#  'a',
#  'sus',
#  'ataqu',
#  'com',
#  'tod',
#  'lder',
#  'en',
#  'cualqui',
#  'part',
#  'del',
#  'mund',
#  'que',
#  'luch',
#  'y',
#  'defiend',
#  'los',
#  'interes',
#  'de',
#  'su',
#  'puebl',
#  'nuestr',
#  'salud',
#  'revolucionari',
#  'a',
#  'la',
#  'central',
#  'obrer',
#  'bolivian',
#  'cob',
#  'en',
#  'el',
#  'aniversari',
#  'de',
#  'su',
#  'creacin',
#  '17',
#  'de',
#  'abril',
#  'de',
#  '1952',
#  'por',
#  'su',
#  'luch',
#  'incans',
#  'por',
#  'la',
#  'dignid',
#  'de',
#  'los',
#  'trabaj',
#  'y',
#  'su',
#  'permanent',
#  'y',
#  'firm',
#  'defens',
#  'de',
#  'la',
#  'soberan',
#  'de',
#  'la',
#  'patri',
#  'y',
#  'la',
#  'nacionalizacin',
#  'de',
#  'los',
#  'recurs',
#  'httpstco1soc5hgnqu',
#  'lament',
#  'el',
#  'fallec',
#  'del',
#  'escritor',
#  'bolivian',
#  'enriqu',
#  'roch',
#  'monroy',
#  'a',
#  'los',
#  '89',
#  'aos',
#  'nuestr',
#  'sent',
#  'condolent',
#  'a',
#  'su',
#  'herman',
#  'ramn',
#  'roch',
#  'monroy',
#  'y',
#  'a',
#  'tod',
#  'su',
#  'famili',
#  'por',
#  'esta',
#  'irrepar',
#  'prdid',
#  'te',
#  'acomp',
#  'en',
#  'tu',
#  'dolor',
#  'herman',
#  'ramn',
#  'httpstcodohel83axw',
#  'lind',
#  'encuentr',
#  'con',
#  'jven',
#  'de',
#  'las',
#  'seis',
#  'feder',
#  'junt',
#  'reflexion',
#  'sobr',
#  'poltic',
#  'econm',
#  'y',
#  'social',
#  'par',
#  'bolivi',
#  'much',
#  'son',
#  'hij',
#  'de',
#  'mis',
#  'compaer',
#  'con',
#  'quien',
#  'luch',
#  'sindical',
#  'nos',
#  'alegr',
#  'ver',
#  'que',
#  'son',
#  'jven',
#  'con',
#  'much',
#  'conviccin',
#  'par',
#  'trabaj',
#  'por',
#  'la',
#  'patri',
#  'httpstcox7lau8y4u3',
#  'si',
#  'el',
#  'cristian',
#  'tien',
#  'com',
#  'principi',
#  'luch',
#  'por',
#  'los',
#  'pobr',
#  'y',
#  'serv',
#  'con',
#  'sacrifici',
#  'a',
#  'la',
#  'gent',
#  'humild',
#  'segu',
#  'la',
#  'fe',
#  'religi',
#  'catlic',
#  'o',
#  'cristian',
#  'es',
#  'asum',
#  'la',
#  'misin',
#  'de',
#  'amar',
#  'la',
#  'vid',
#  'y',
#  'a',
#  'la',
#  'human',
#  'en',
#  'hermand',
#  'y',
#  'solidar',
#  'httpstco1zkxxgmju0',
#  'nos',
#  'da',
#  'much',
#  'alegr',
#  'lleg',
#  'a',
#  'tarij',
#  'en',
#  'el',
#  'da',
#  'que',
#  'celebr',
#  'su',
#  'aniversari',
#  'hem',
#  'socializ',
#  'la',
#  'inscripcin',
#  'de',
#  'nuev',
#  'milit',
#  'del',
#  'masipsp',
#  'y',
#  'sostuv',
#  'una',
#  'reunin',
#  'con',
#  'dirigent',
#  'y',
#  'autor',
#  'del',
#  'departament',
#  'httpstcos4tee4bcnv',
#  'estuv',
#  'en',
#  'sucr',
#  'chuquisac',
#  'par',
#  'socializ',
#  'la',
#  'inscripcin',
#  'de',
#  'nuev',
#  'milit',
#  'y',
#  'par',
#  'sosten',
#  'una',
#  'reunin',
#  'con',
#  'dirigent',
#  'y',
#  'autor',
#  'del',
#  'departament',
#  'httpstcownntrsprdh',
#  'en',
#  'este',
#  'viernessant',
#  'nos',
#  'unim',
#  'a',
#  'las',
#  'reflexion',
#  'y',
#  'oracion',
#  'de',
#  'nuestr',
#  'puebl',
#  'que',
#  'recuerd',
#  'el',
#  'sacrifici',
#  'de',
#  'jesucrist',
#  'por',
#  'la',
#  'human',
#  'una',
#  'enseanz',
#  'import',
#  'del',
#  'cristian',
#  'es',
#  'luch',
#  'por',
#  'los',
#  'ms',
#  'pobr',
#  'la',
#  'solidar',
#  'es',
#  'la',
#  'bas',
#  'de',
#  'una',
#  'socied',
#  'con',
#  'respet',
#  'y',
#  'paz',
#  'social',
#  'httpstcovjdkt6q5py',
#  'rend',
#  'nuestr',
#  'homenaj',
#  'al',
#  'herman',
#  'puebl',
#  'de',
#  'la',
#  'chur',
#  'tarij',
#  'en',
#  'el',
#  '205',
#  'aniversari',
#  'de',
#  'la',
#  'batall',
#  'de',
#  'la',
#  'tabl',
#  'que',
#  'nos',
#  'tra',
#  'a',
#  'la',
#  'memori',
#  'la',
#  'victori',
#  'decis',
#  'de',
#  'eustaqui',
#  'mot',
#  'mndez',
#  'y',
#  'sus',
#  'montoner',
#  'sobr',
#  'las',
#  'fuerz',
#  'realist',
#  'tarij',
#  'es',
#  'tierr',
#  'fecund',
#  'de',
#  'amor',
#  'por',
#  'bolivi',
#  'httpstcoltnleudzcr',
#  'nuestr',
#  'dign',
#  'represent',
#  'anglic',
#  'barri',
#  'nos',
#  'llen',
#  'de',
#  'orgull',
#  'y',
#  'dej',
#  'en',
#  'alto',
#  'el',
#  'nombr',
#  'de',
#  'nuestr',
#  'quer',
#  'bolivi',
#  'medall',
#  'de',
#  'oro',
#  'y',
#  'campeon',
#  'en',
#  'la',
#  'categor',
#  'open',
#  'dam',
#  'del',
#  'xxxiii',
#  'campeonat',
#  'panamerican',
#  'de',
#  'rquet',
#  'es',
#  'un',
#  'gran',
#  'ejempl',
#  'de',
#  'superacin',
#  'de',
#  'las',
#  'nuev',
#  'gener',
#  'httpstcouo5jeg7qm2',
#  'con',
#  'dirigent',
#  'de',
#  'san',
#  'julin',
#  'y',
#  'yapac',
#  'y',
#  'de',
#  'intercultural',
#  'de',
#  'sant',
#  'cruz',
#  'coincid',
#  'en',
#  'fortalec',
#  'la',
#  'unid',
#  'par',
#  'defend',
#  'la',
#  'patri',
#  'y',
#  'nuestr',
#  'revolucin',
#  'democrt',
#  'y',
#  'cultural',
#  'en',
#  'reunion',
#  'desarroll',
#  'el',
#  'mart',
#  'y',
#  'hoy',
#  'prxim',
#  'reunin',
#  'ser',
#  'con',
#  'intercultural',
#  'del',
#  'departament',
#  'httpstcoo7vvbbbuy8',
#  'nuestr',
#  'profund',
#  'pes',
#  'por',
#  'la',
#  'part',
#  'del',
#  'hno',
#  'freddy',
#  'rincn',
#  'estrell',
#  'del',
#  'ftbol',
#  'latinoamerican',
#  'y',
#  'mundial',
#  'que',
#  'fue',
#  'baluart',
#  'de',
#  'la',
#  'seleccin',
#  'de',
#  'colombi',
#  'y',
#  'grand',
#  'equip',
#  'com',
#  'el',
#  'corinthians',
#  'y',
#  'real',
#  'madr',
#  'nuestr',
#  'solidar',
#  'a',
#  'su',
#  'famili',
#  'y',
#  'a',
#  'la',
#  'hinch',
#  ...]

# %%
import nltk
from nltk import tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# %%
#Removing all Stop Words

stem2 = []

for word in stem:
    if word not in nlp.Defaults.stop_words:
        stem2.append(word)

stem2
# Out:
# ['desd',
#  'las',
#  '0500',
#  'desarroll',
#  'una',
#  'reunin',
#  'de',
#  'evaluacin',
#  'y',
#  'planificacin',
#  'poltic',
#  'con',
#  'el',
#  'gobern',
#  'de',
#  'cochabamb',
#  'y',
#  'asamblest',
#  'nacional',
#  'y',
#  'departamental',
#  'alcald',
#  'y',
#  'concejal',
#  'httpstcozypai614hf',
#  'el',
#  'masipsp',
#  'es',
#  'una',
#  'organizacin',
#  'poltic',
#  'viv',
#  'que',
#  'debat',
#  'y',
#  'resuelv',
#  'intern',
#  'sus',
#  'contradiccion',
#  'la',
#  'hor',
#  'de',
#  'defend',
#  'la',
#  'dignid',
#  'soberan',
#  'y',
#  'econom',
#  'de',
#  'nuestr',
#  'puebl',
#  'actu',
#  'con',
#  'la',
#  'verd',
#  'unid',
#  'y',
#  'solidar',
#  'sin',
#  'mezquind',
#  'ni',
#  'falsed',
#  'som',
#  'puebl',
#  'som',
#  'mas',
#  'diferent',
#  'de',
#  'opositor',
#  'que',
#  'se',
#  'dedic',
#  'sus',
#  'camp',
#  'de',
#  'odi',
#  'y',
#  'racism',
#  'contr',
#  'evo',
#  'nuestr',
#  'instrument',
#  'poltic',
#  'que',
#  'lleg',
#  'al',
#  'gobiern',
#  'graci',
#  'al',
#  'vot',
#  'del',
#  'puebl',
#  'tien',
#  'un',
#  'plan',
#  'de',
#  'trabaj',
#  'par',
#  'reconstru',
#  'la',
#  'econom',
#  'y',
#  'la',
#  'democraci',
#  'destru',
#  'por',
#  'el',
#  'rgim',
#  'de',
#  'fact',
#  'hag',
#  'un',
#  'llam',
#  'nuestr',
#  'milit',
#  'dej',
#  'confund',
#  'con',
#  'las',
#  'mentir',
#  'e',
#  'intrig',
#  'de',
#  'la',
#  'derech',
#  'golpist',
#  'y',
#  'sus',
#  'medi',
#  'que',
#  'busc',
#  'divid',
#  'y',
#  'desestabiliz',
#  'la',
#  'unid',
#  'del',
#  'bloqu',
#  'popul',
#  'del',
#  'masipsp',
#  'est',
#  'intact',
#  'nuestr',
#  'organiz',
#  'trabaj',
#  'de',
#  'la',
#  'man',
#  'con',
#  'nuestr',
#  'gobiern',
#  'fuim',
#  'al',
#  'municipi',
#  'de',
#  'anzald',
#  'comun',
#  'de',
#  'tijrask',
#  'dond',
#  'visit',
#  'la',
#  'repres',
#  'inici',
#  'en',
#  'nuestr',
#  'gestin',
#  'que',
#  'abastec',
#  '170',
#  'ha',
#  'de',
#  'cultiv',
#  'nos',
#  'alegr',
#  'su',
#  'pront',
#  'inauguracin',
#  'httpstcohzlojefam5',
#  'nuestr',
#  'agradec',
#  'al',
#  'herman',
#  'hernn',
#  'colqu',
#  'alcald',
#  'de',
#  'tor',
#  'tor',
#  'autor',
#  'y',
#  'puebl',
#  'del',
#  'municipi',
#  'en',
#  'provinci',
#  'charc',
#  'departament',
#  'de',
#  'pot',
#  'por',
#  'su',
#  'clid',
#  'recib',
#  'y',
#  'la',
#  'visit',
#  'al',
#  'parqu',
#  'nacional',
#  'de',
#  'tor',
#  'tor',
#  'de',
#  'huell',
#  'de',
#  'dinosauri',
#  'cavern',
#  'y',
#  'siti',
#  'milenari',
#  'httpstcobqrdav1g34',
#  'recorr',
#  'hoy',
#  'la',
#  'majestu',
#  'e',
#  'impresion',
#  'cavern',
#  'de',
#  'umajalant',
#  'en',
#  'tor',
#  'tor',
#  'la',
#  'ms',
#  'grand',
#  'de',
#  'latin',
#  'con',
#  'roc',
#  'milenari',
#  'agu',
#  'cristalin',
#  'y',
#  'murcilag',
#  'que',
#  'nos',
#  'hic',
#  'viv',
#  'una',
#  'aventur',
#  'maravill',
#  'invit',
#  'al',
#  'puebl',
#  'bolivian',
#  'y',
#  'al',
#  'mund',
#  'visit',
#  'les',
#  'encant',
#  'httpstcopwvv3f4ydv',
#  'la',
#  'prens',
#  'quier',
#  'hac',
#  'aparec',
#  'divid',
#  'y',
#  'enfrent',
#  'hay',
#  'nad',
#  'de',
#  'eso',
#  'estam',
#  'viend',
#  'y',
#  'convenc',
#  'de',
#  'que',
#  'hay',
#  'divisin',
#  'del',
#  'masipsp',
#  'en',
#  'el',
#  'recorr',
#  'que',
#  'hac',
#  'por',
#  'distint',
#  'departament',
#  'de',
#  'bolivi',
#  'organiz',
#  'el',
#  'registr',
#  'de',
#  'milit',
#  'lo',
#  'ms',
#  'import',
#  'es',
#  'la',
#  'unid',
#  'en',
#  'bas',
#  'un',
#  'movimient',
#  'poltic',
#  'que',
#  'garantiz',
#  'la',
#  'liberacin',
#  'de',
#  'la',
#  'patri',
#  'con',
#  'un',
#  'program',
#  'par',
#  'tiemp',
#  'que',
#  'vien',
#  'del',
#  'puebl',
#  'con',
#  'un',
#  'masipsp',
#  'que',
#  'claudic',
#  'en',
#  'su',
#  'posicin',
#  'ideolg',
#  'antimperial',
#  'y',
#  'anticolonial',
#  'com',
#  'movimient',
#  'poltic',
#  'ms',
#  'grand',
#  'de',
#  'la',
#  'histori',
#  'en',
#  'bolivi',
#  'el',
#  'masipsp',
#  'y',
#  'organiz',
#  'social',
#  'pod',
#  'actu',
#  'en',
#  'funcin',
#  'las',
#  'intencion',
#  'de',
#  'la',
#  'derech',
#  'par',
#  'divid',
#  'reflej',
#  'en',
#  'los',
#  'grand',
#  'titular',
#  'de',
#  'su',
#  'prens',
#  'porqu',
#  'con',
#  'el',
#  'puebl',
#  'un',
#  'program',
#  'que',
#  'cumpl',
#  'las',
#  'port',
#  'de',
#  'la',
#  'prens',
#  'de',
#  'derech',
#  'reflej',
#  'las',
#  'estrategi',
#  'par',
#  'divid',
#  'porqu',
#  'nos',
#  'tien',
#  'mied',
#  'les',
#  'molest',
#  'que',
#  'nuestr',
#  'movimient',
#  'poltic',
#  'mas',
#  'ipsp',
#  'est',
#  'integr',
#  'por',
#  'movimient',
#  'social',
#  'del',
#  'rea',
#  'urban',
#  'y',
#  'rural',
#  'de',
#  'bolivi',
#  'y',
#  'teng',
#  'un',
#  'program',
#  'ms',
#  'del',
#  'bicentenari',
#  'los',
#  'afan',
#  'de',
#  'la',
#  'derech',
#  'desd',
#  'que',
#  'el',
#  'puebl',
#  'retom',
#  'el',
#  'gobiern',
#  'por',
#  'la',
#  'va',
#  'democrt',
#  'es',
#  'divid',
#  'al',
#  'masipsp',
#  'dec',
#  'primer',
#  'evo',
#  'mand',
#  'luch',
#  'y',
#  'ahor',
#  'dic',
#  'que',
#  'evo',
#  'dar',
#  'golp',
#  'luch',
#  'en',
#  'el',
#  'fond',
#  'nos',
#  'tien',
#  'mied',
#  'y',
#  'eso',
#  'deb',
#  'preocup',
#  'lo',
#  'import',
#  'es',
#  'la',
#  'unid',
#  '14',
#  'los',
#  'enemig',
#  'de',
#  'evo',
#  'son',
#  'amig',
#  'del',
#  'imperi',
#  'y',
#  'sumis',
#  'l',
#  'por',
#  'lo',
#  'que',
#  'nos',
#  'molest',
#  'que',
#  'habl',
#  'en',
#  'nuestr',
#  'contr',
#  'estam',
#  'acostumbr',
#  'sus',
#  'ataqu',
#  'com',
#  'tod',
#  'lder',
#  'en',
#  'cualqui',
#  'del',
#  'mund',
#  'que',
#  'luch',
#  'y',
#  'defiend',
#  'los',
#  'interes',
#  'de',
#  'su',
#  'puebl',
#  'nuestr',
#  'salud',
#  'revolucionari',
#  'la',
#  'central',
#  'obrer',
#  'bolivian',
#  'cob',
#  'en',
#  'el',
#  'aniversari',
#  'de',
#  'su',
#  'creacin',
#  '17',
#  'de',
#  'abril',
#  'de',
#  '1952',
#  'por',
#  'su',
#  'luch',
#  'incans',
#  'por',
#  'la',
#  'dignid',
#  'de',
#  'los',
#  'trabaj',
#  'y',
#  'su',
#  'permanent',
#  'y',
#  'firm',
#  'defens',
#  'de',
#  'la',
#  'soberan',
#  'de',
#  'la',
#  'patri',
#  'y',
#  'la',
#  'nacionalizacin',
#  'de',
#  'los',
#  'recurs',
#  'httpstco1soc5hgnqu',
#  'lament',
#  'el',
#  'fallec',
#  'del',
#  'escritor',
#  'bolivian',
#  'enriqu',
#  'roch',
#  'monroy',
#  'los',
#  '89',
#  'aos',
#  'nuestr',
#  'sent',
#  'condolent',
#  'su',
#  'herman',
#  'ramn',
#  'roch',
#  'monroy',
#  'y',
#  'tod',
#  'su',
#  'famili',
#  'por',
#  'esta',
#  'irrepar',
#  'prdid',
#  'te',
#  'acomp',
#  'en',
#  'tu',
#  'dolor',
#  'herman',
#  'ramn',
#  'httpstcodohel83axw',
#  'lind',
#  'encuentr',
#  'con',
#  'jven',
#  'de',
#  'las',
#  'seis',
#  'feder',
#  'junt',
#  'reflexion',
#  'sobr',
#  'poltic',
#  'econm',
#  'y',
#  'social',
#  'par',
#  'bolivi',
#  'son',
#  'hij',
#  'de',
#  'mis',
#  'compaer',
#  'con',
#  'quien',
#  'luch',
#  'sindical',
#  'nos',
#  'alegr',
#  'ver',
#  'que',
#  'son',
#  'jven',
#  'con',
#  'conviccin',
#  'par',
#  'trabaj',
#  'por',
#  'la',
#  'patri',
#  'httpstcox7lau8y4u3',
#  'si',
#  'el',
#  'cristian',
#  'tien',
#  'com',
#  'principi',
#  'luch',
#  'por',
#  'los',
#  'pobr',
#  'y',
#  'serv',
#  'con',
#  'sacrifici',
#  'la',
#  'gent',
#  'humild',
#  'segu',
#  'la',
#  'fe',
#  'religi',
#  'catlic',
#  'o',
#  'cristian',
#  'es',
#  'asum',
#  'la',
#  'misin',
#  'de',
#  'amar',
#  'la',
#  'vid',
#  'y',
#  'la',
#  'human',
#  'en',
#  'hermand',
#  'y',
#  'solidar',
#  'httpstco1zkxxgmju0',
#  'nos',
#  'da',
#  'alegr',
#  'lleg',
#  'tarij',
#  'en',
#  'el',
#  'da',
#  'que',
#  'celebr',
#  'su',
#  'aniversari',
#  'hem',
#  'socializ',
#  'la',
#  'inscripcin',
#  'de',
#  'nuev',
#  'milit',
#  'del',
#  'masipsp',
#  'y',
#  'sostuv',
#  'una',
#  'reunin',
#  'con',
#  'dirigent',
#  'y',
#  'autor',
#  'del',
#  'departament',
#  'httpstcos4tee4bcnv',
#  'estuv',
#  'en',
#  'sucr',
#  'chuquisac',
#  'par',
#  'socializ',
#  'la',
#  'inscripcin',
#  'de',
#  'nuev',
#  'milit',
#  'y',
#  'par',
#  'sosten',
#  'una',
#  'reunin',
#  'con',
#  'dirigent',
#  'y',
#  'autor',
#  'del',
#  'departament',
#  'httpstcownntrsprdh',
#  'en',
#  'este',
#  'viernessant',
#  'nos',
#  'unim',
#  'las',
#  'reflexion',
#  'y',
#  'oracion',
#  'de',
#  'nuestr',
#  'puebl',
#  'que',
#  'recuerd',
#  'el',
#  'sacrifici',
#  'de',
#  'jesucrist',
#  'por',
#  'la',
#  'human',
#  'una',
#  'enseanz',
#  'import',
#  'del',
#  'cristian',
#  'es',
#  'luch',
#  'por',
#  'los',
#  'ms',
#  'pobr',
#  'la',
#  'solidar',
#  'es',
#  'la',
#  'bas',
#  'de',
#  'una',
#  'socied',
#  'con',
#  'respet',
#  'y',
#  'paz',
#  'social',
#  'httpstcovjdkt6q5py',
#  'rend',
#  'nuestr',
#  'homenaj',
#  'al',
#  'herman',
#  'puebl',
#  'de',
#  'la',
#  'chur',
#  'tarij',
#  'en',
#  'el',
#  '205',
#  'aniversari',
#  'de',
#  'la',
#  'batall',
#  'de',
#  'la',
#  'tabl',
#  'que',
#  'nos',
#  'tra',
#  'la',
#  'memori',
#  'la',
#  'victori',
#  'decis',
#  'de',
#  'eustaqui',
#  'mot',
#  'mndez',
#  'y',
#  'sus',
#  'montoner',
#  'sobr',
#  'las',
#  'fuerz',
#  'realist',
#  'tarij',
#  'es',
#  'tierr',
#  'fecund',
#  'de',
#  'amor',
#  'por',
#  'bolivi',
#  'httpstcoltnleudzcr',
#  'nuestr',
#  'dign',
#  'represent',
#  'anglic',
#  'barri',
#  'nos',
#  'llen',
#  'de',
#  'orgull',
#  'y',
#  'dej',
#  'en',
#  'alto',
#  'el',
#  'nombr',
#  'de',
#  'nuestr',
#  'quer',
#  'bolivi',
#  'medall',
#  'de',
#  'oro',
#  'y',
#  'campeon',
#  'en',
#  'la',
#  'categor',
#  'open',
#  'dam',
#  'del',
#  'xxxiii',
#  'campeonat',
#  'panamerican',
#  'de',
#  'rquet',
#  'es',
#  'un',
#  'gran',
#  'ejempl',
#  'de',
#  'superacin',
#  'de',
#  'las',
#  'nuev',
#  'gener',
#  'httpstcouo5jeg7qm2',
#  'con',
#  'dirigent',
#  'de',
#  'san',
#  'julin',
#  'y',
#  'yapac',
#  'y',
#  'de',
#  'intercultural',
#  'de',
#  'sant',
#  'cruz',
#  'coincid',
#  'en',
#  'fortalec',
#  'la',
#  'unid',
#  'par',
#  'defend',
#  'la',
#  'patri',
#  'y',
#  'nuestr',
#  'revolucin',
#  'democrt',
#  'y',
#  'cultural',
#  'en',
#  'reunion',
#  'desarroll',
#  'el',
#  'mart',
#  'y',
#  'hoy',
#  'prxim',
#  'reunin',
#  'ser',
#  'con',
#  'intercultural',
#  'del',
#  'departament',
#  'httpstcoo7vvbbbuy8',
#  'nuestr',
#  'profund',
#  'pes',
#  'por',
#  'la',
#  'del',
#  'hno',
#  'freddy',
#  'rincn',
#  'estrell',
#  'del',
#  'ftbol',
#  'latinoamerican',
#  'y',
#  'mundial',
#  'que',
#  'fue',
#  'baluart',
#  'de',
#  'la',
#  'seleccin',
#  'de',
#  'colombi',
#  'y',
#  'grand',
#  'equip',
#  'com',
#  'el',
#  'corinthians',
#  'y',
#  'real',
#  'madr',
#  'nuestr',
#  'solidar',
#  'su',
#  'famili',
#  'y',
#  'la',
#  'hinch',
#  'que',
#  'lament',
#  'su',
#  'ausenci',
#  'httpstcoxxtnacnxnn',
#  'al',
#  'defend',
#  'golpist',
#  'derech',
#  'que',
#  'enjuici',
#  'por',
#  'asalt',
#  'el',
#  'pod',
#  'rob',
#  'al',
#  'estad',
#  'y',
#  'masacr',
#  'nuestr',
#  'herman',
#  'eeuu',
#  'busc',
#  'impun',
#  'par',
#  'esos',
#  'delit',
#  'y',
#  'violacion',
#  'de',
#  'ddhh',
#  'busc',
#  'la',
#  'desestabilizacin',
#  'poltic',
#  'par',
#  'imped',
#  'la',
#  'justici',
#  'que',
#  'pid',
#  'las',
#  ...]

# %%
df1 = pd.DataFrame(stem2)

df1 = df1[0].value_counts()

#df
#df['freq'] = df.groupby(0)[0].transform('count')
#df['freq'] = df.groupby(0)[0].transform('count')
#df.sort_values(by = ('freq'), ascending=False)

# %%
df1
# Out:
# de         91
# y          64
# la         64
# que        32
# el         31
#            ..
# pas         1
# jerarqu     1
# vid         1
# orgull      1
# hug         1
# Name: 0, Length: 499, dtype: int64

# %%
#This will give frequencies of our words

from nltk.probability import FreqDist

freqdoctor = FreqDist()

for words in df1:
    freqdoctor[words] += 1

freqdoctor
# Out:
# FreqDist({1: 354, 2: 66, 3: 25, 4: 11, 5: 9, 6: 6, 7: 5, 8: 3, 64: 2, 20: 2, ...})

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#This is a simple plot that shows the top 20 words being used
#df.plot(20)

df1 = df1[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df1.values, df1.index, alpha=0.8)
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
# Out:
# C:\Users\tania\anaconda3\envs\py36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text + ' - ' + ent.label_ + ' - ' + str(spacy.explain(ent.label_)))

# %%
str1 = " " 
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df6 = pd.DataFrame(label, columns = ['Word','Entity'])

df7 = df6.where(df6['Entity'] == 'ORG')

df7 = df7['Word'].value_counts()

# %%
df1 = df7[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df1.values, df1.index, alpha=0.8)
plt.title('Top Organizations Mentioned')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
# Out:
# C:\Users\tania\anaconda3\envs\py36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
str1 = " " 
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df10 = pd.DataFrame(label, columns = ['Word','Entity'])

df10 = df10.where(df10['Entity'] == 'PERSON')

df11 = df10['Word'].value_counts()

# %%
df1 = df11[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df1.values, df1.index, alpha=0.8)
plt.title('Top People Mentioned')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
# Out:
# C:\Users\tania\anaconda3\envs\py36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#To make predictions.

# %%
import requests
client = tweepy.Client( bearer_token=bearer_token, 
                        consumer_key=consumer_key, 
                        consumer_secret=consumer_secret, 
                        access_token=access_token, 
                        access_token_secret=access_token_secret, 
                        return_type = requests.Response,
                        wait_on_rate_limit=True)

# %%
df.iloc[9]['text']
# Out:
# 'Como movimiento político más grande de la historia en Bolivia, el MAS-IPSP y organizaciones sociales, no podemos actuar en función a las intenciones de la derecha para dividirnos reflejadas en los grandes titulares de su prensa porque tenemos con el pueblo un programa que cumplir'

# %%
port_stem = PorterStemmer()
# loaded_vector2= pickle.load(open('./tfidf_X_test.pkl', 'rb'))
loaded_vector2= pickle.load(open('tfidf_X_train.pkl', 'rb'))
loaded_vector=pickle.load(open('vectorizer.pkl', 'rb'))
loaded_model = pickle.load(open('modelXGB.pkl', 'rb'))

def predict(text):    
        stemmed_content = []
        stemmed_content = re.sub('[^a-zA-Z\u00C0-\u024F]', ' ', text)
        stemmed_content = stemmed_content.lower()
        stemmed_content = stemmed_content.split()
        stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('spanish')]
        test_processed = ' '.join(stemmed_content)
        print(test_processed)
        test_processed=[test_processed]
        #tfidf_v.fit_transform(test_processed)
        test_input = loaded_vector.transform(test_processed)
        print(test_input)
        prediction = loaded_model.predict(test_input)
        return prediction
    
# prediction=predict(df.iloc[0]['text'])

# if (prediction[0]==0):
#     print('The news is Fake')
#     df.to_csv("tweets.csv")

# else:
#     print('The news is Real')

for i in range(len(df)):
    prediction=predict(df.iloc[i]['text'])

    if (prediction[0]==0):
        print('The news is Fake')
        df.to_csv("tweets.csv")

    else:
        print('The news is Real')
